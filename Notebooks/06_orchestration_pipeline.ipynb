# %% [markdown]
# ### Pipeline Orchestration
#
# This notebook orchestrates the complete pipeline:
#
# Bronze → Silver → Gold → Production → Validation

# %%
dbutils.notebook.run("01_bronze_ingestion",0)

dbutils.notebook.run("02_silver_transformations",0)

dbutils.notebook.run("03_gold_analytics",0)

dbutils.notebook.run("04_production_pipeline",0)

dbutils.notebook.run("05_validation_report",0)
